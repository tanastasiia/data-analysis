# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from skimage import io
from sklearn.utils import shuffle
from sklearn.metrics import pairwise_distances_argmin
from sklearn.metrics import silhouette_score
from sklearn.mixture import GaussianMixture
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer #word stemmer class
from wordcloud import WordCloud, STOPWORDS
from nltk import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression #classification model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, f1_score # performance evaluation criteria
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
#nltk.download('wordnet')
#nltk.download('stopwords')

# %% [markdown]
# ## 1. PCA & TSNE

# %%
df = pd.read_csv('datasets/mobile_price/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
sc = StandardScaler()
df_x = sc.fit_transform(df.drop(columns = {'price_range'}))
df_y = df.price_range
df_x[:3]
# Out:
# array([[-0.90259726, -0.9900495 ,  0.83077942, -1.01918398, -0.76249466,
#         -1.04396559, -1.38064353,  0.34073951,  1.34924881, -1.10197128,
#         -1.3057501 , -1.40894856, -1.14678403,  0.39170341, -0.78498329,
#          0.2831028 ,  1.46249332, -1.78686097, -1.00601811,  0.98609664],
#        [-0.49513857,  1.0100505 , -1.2530642 ,  0.98117712, -0.99289039,
#          0.95788598,  1.15502422,  0.68754816, -0.12005944, -0.66476784,
#         -0.64598879,  0.58577791,  1.70446468,  0.46731702,  1.11426556,
#         -0.63531667, -0.73426721,  0.55964063,  0.99401789, -1.01409939],
#        [-1.5376865 ,  1.0100505 , -1.2530642 ,  0.98117712, -0.53209893,
#          0.95788598,  0.49354568,  1.38116548,  0.13424391,  0.20963905,
#         -0.64598879,  1.39268422,  1.07496821,  0.44149774, -0.31017108,
#         -0.86492153, -0.36814045,  0.55964063,  0.99401789, -1.01409939]])

# %%
pca = PCA(n_components=2, svd_solver='full')
x_pca = pca.fit_transform(df_x, )

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x_pca[:, 0], x_pca[:, 1], hue=df_y)

# %%
pca.explained_variance_
# Out:
# array([1.67809669, 1.62330659])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.08386288, 0.08112475])

# %% [markdown]
# ### TSNE

# %%
ts = TSNE(n_components=2, init="pca")
x_tsne = ts.fit_transform(df.drop(columns = {'price_range'}))

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x_tsne[:, 0], x_tsne[:, 1], hue=df_y)

# %%
x_tsne.shape
# Out:
# (2000, 2)

# %% [markdown]
# ## 2.1 Quantization

# %%
img = io.imread('datasets/big-blue-whale.jpg')
print(img.shape)
# Out:
# (1800, 2880, 3)

# %%
w, h, d = original_shape = tuple(img.shape)

# %%
image_array = np.reshape(img, (w * h, d))

# %%
n_colors = 64
image_array_sample = shuffle(image_array, random_state=0, n_samples=1_000)
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)

def recreate_image(codebook, labels, w, h):
    return codebook[labels].reshape(w, h, -1)

# %%
plt.imshow(img)

# %%
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %%
n_colors = 32
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %%
n_colors = 16
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %%
n_colors = 8
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %%
n_colors = 4
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %%
n_colors = 2
kmeans = KMeans(n_clusters=n_colors, random_state=0).fit(image_array_sample)
labels = kmeans.predict(image_array)

codebook_random = shuffle(image_array, random_state=0, n_samples=n_colors)
labels_random = pairwise_distances_argmin(codebook_random, image_array, axis=0)
plt.imshow(recreate_image(kmeans.cluster_centers_, labels, w, h).astype(int))

# %% [markdown]
# ## 2.2 Generate

# %%
size = 1000

mean1 = [0, 3]
cov1 = [[4, 2], [2, 3]]
x1 = np.random.multivariate_normal(mean1, cov1, size)

mean2 = [3, 1]
cov2 = [[2, 1], [1,2]]
x2 = np.random.multivariate_normal(mean2, cov2, size)

X = np.concatenate([x1, x2])
y = np.array([0] * size + [1] * size)
X, y = shuffle(X, y, random_state=42)
plt.scatter(X[:, 0], X[:, 1], s=3, c=y)

# %%
for i in range(2, 10):
    gmm = GaussianMixture(n_components = i, covariance_type = 'full')
    gmm_labels = gmm.fit_predict(X)
    silhouette = silhouette_score(X, gmm_labels)
    print("n_clusters: ", i, " -- silhouette score: ", silhouette)
# Out:
# n_clusters:  2  -- silhouette score:  0.3870319520224269
# n_clusters:  3  -- silhouette score:  0.38974339864587126
# n_clusters:  4  -- silhouette score:  0.3585553342972426
# n_clusters:  5  -- silhouette score:  0.35094514996049814
# n_clusters:  6  -- silhouette score:  0.30788342573946703
# n_clusters:  7  -- silhouette score:  0.3085443692519116
# n_clusters:  8  -- silhouette score:  0.31883448548518445
# n_clusters:  9  -- silhouette score:  0.3090926322835649

# %%
GMM = GaussianMixture(n_components=2, covariance_type='full')
GMM.fit(X)
print('means ')
print(GMM.means_)
# Out:
# means
# [[-0.23932827  3.0650658 ]
#  [ 2.84322997  1.15364298]]

# %%
print('Covariances: ', GMM.covariances_)
print("Weights:", GMM.weights_)
# Out:
# Covariances:  [[[4.06084193 2.40178189]
#   [2.40178189 3.22214301]]
#
#  [[2.10635393 0.82462703]
#   [0.82462703 2.20538641]]]
# Weights: [0.44102221 0.55897779]

# %%
labels = GMM.predict(X)

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.set_title('GMM')
ax1.scatter(X[:, 0], X[:, 1], c=labels, s=3)
ax2.set_title("Original")
ax2.scatter(X[:, 0], X[:, 1], c=y, s=3)

# %%
mean11 = GMM.means_[0]
cov11 = GMM.covariances_[0]
x11 = np.random.multivariate_normal(mean11, cov11, size)
mean21 = GMM.means_[1]
cov21 = GMM.covariances_[1]
x21 = np.random.multivariate_normal(mean21, cov21, size)
X1 = np.concatenate([x11, x21])
y1 = np.array([0] * size + [1] * size)
X1, y1 = shuffle(X1, y1, random_state=42)

# %%
plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], s=8, c=y)
plt.subplot(1, 2, 2)
plt.scatter(X1[:, 0], X1[:, 1], s=8, c=y1)

# %% [markdown]
# ## 3 Wordcloud

# %%
df1 = pd.read_csv('datasets/SMSSpamCollection.tsv', sep='\t')

# %%
df1.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df1.isna().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
print(len(df1[df1.label == 'ham']), 'Ham')
print(len(df1[df1.label == 'spam']), 'Spam')
# Out:
# 4825 Ham
# 747 Spam

# %%
lemma = WordNetLemmatizer()
stopWords = stopwords.words('english')

# %%
## preprocessing
def normalizer(message):
    message = re.sub('[^a-zA-Z]', ' ', message).lower().split()
    message = [word for word in message if not word in set(stopwords.words('english'))]
    message = [lemma.lemmatize(word) for word in message]
    message = " ".join(message)
    return message

# %%
df1['normalized_text'] = df1.message.apply(normalizer)

# %%
df1.head()
# Out:
#   label                                            message  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                      normalized_text
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# 2  free entry wkly comp win fa cup final tkts st ...
# 3                u dun say early hor u c already say
# 4                nah think go usf life around though

# %%
all_words = " ".join(df1.normalized_text)
spam_words = " ".join(df1[df1.label=='spam'].normalized_text)

# %%
wordcloud = WordCloud(height=2000, width=2000, stopwords=STOPWORDS, background_color='white')
wordcloud = wordcloud.generate(all_words)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
#Spam
wordcloud = WordCloud(height=2000, width=2000, stopwords=STOPWORDS, background_color='white')
wordcloud = wordcloud.generate(spam_words)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
corpus = [df1.normalized_text[i] for i in range(0,len(df1))]
cv = CountVectorizer(stop_words=stopwords.words('english'))
cv.fit(corpus)
# Out:
# CountVectorizer(stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours',
#                             'ourselves', 'you', "you're", "you've", "you'll",
#                             "you'd", 'your', 'yours', 'yourself', 'yourselves',
#                             'he', 'him', 'his', 'himself', 'she', "she's",
#                             'her', 'hers', 'herself', 'it', "it's", 'its',
#                             'itself', ...])

# %%
# creating dense matrix
X = cv.transform(corpus).toarray()
def rr(x):
    if( x == 'spam'):
        return 1
    return 0
y = df1.label.apply(rr).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
### TfidfVectorizer
tfidf = TfidfVectorizer(ngram_range=(1,3), min_df=10, stop_words=stopwords.words('english'))
X1 = tfidf.fit_transform(corpus)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y, test_size=0.33, random_state=42)
classifier2 =  RandomForestClassifier(n_estimators=200, max_depth=200).fit(X1_train, y1_train.astype(np.int64))

classifier2.fit(X1_train, y1_train)
# Out:
# RandomForestClassifier(max_depth=200, n_estimators=200)

# %%
y1_pred = classifier2.predict(X1_test)
y1_prob = classifier2.predict_proba(X1_test)

# %%
print(f1_score(y1_test, y1_pred))
print(classification_report(y1_test, y1_pred))
print(confusion_matrix(y1_test, y1_pred))
# Out:
# 0.9396551724137931
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1593
#            1       1.00      0.89      0.94       246
#
#     accuracy                           0.98      1839
#    macro avg       0.99      0.94      0.97      1839
# weighted avg       0.99      0.98      0.98      1839
#
# [[1593    0]
#  [  28  218]]

# %% [markdown]
# ## LDA

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(1, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
n_components = 5
n_top_words = 10

# %%
vectorizer = CountVectorizer(stop_words='english')

data_vectorized = vectorizer.fit_transform(corpus)

lda = LatentDirichletAllocation(n_components=n_components, random_state=0)

lda.fit(data_vectorized)

feature_names = vectorizer.get_feature_names()

plot_top_words(lda, feature_names, n_top_words, 'Topics in LDA model')
